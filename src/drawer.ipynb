# %%
import pickle
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
with open("../stats/fasion_mnist_Unet_linear.pkl", "rb") as f:
    linear_losses = pickle.load(f)
with open("../stats/fasion_mnist_Unet_cosine.pkl", "rb") as f:
    cosine_losses = pickle.load(f)
with open("../stats/fasion_mnist_DEQ_anderson_24.pkl", "rb") as f:
    deq_12 = pickle.load(f)
with open("../stats/fasion_mnist_DEQ_anderson_12_time.pkl", "rb") as f:
    deq_12_time = pickle.load(f)
with open("../stats/fasion_mnist_DEQ_anderson_48_time.pkl", "rb") as f:
    deq_48_time = pickle.load(f)

# %%
plt.plot(cosine_losses, label="U-net (cosine)")
plt.plot(linear_losses, label="U-net (linear)")
plt.plot(deq_12, label="DEQ (12 channels, time-blind)")
plt.plot(deq_12_time, label="DEQ (12 channels)")
plt.plot(deq_48_time, label="DEQ (48 channels)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Baselines performance on Fashion-MNIST")
plt.legend()
